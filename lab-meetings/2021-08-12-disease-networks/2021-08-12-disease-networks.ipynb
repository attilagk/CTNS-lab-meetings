# %% [markdown]
# Some ideas for the projects of Anjali and Attila

# %% [markdown]
# 1. Find high confidence Alzheimer's disease (AD) genes from literature (besides the ones we already have)
#     * Haeky lab will produce a high confidence AD gene set for us
# 1. AD candidate gene prioritization
#     * AD candidate gene set: [DisGeNET database](https://www.disgenet.org/)? > 3,000 AD associated genes
#     * AD seed gene set: high confidence AD genes
#     * prioritization tool [Endeavour](https://endeavour.esat.kuleuven.be/)?
#         * set up and run standalone version on NIA cloud
# 1. disease networks
#     * patho-mechanistic insights to comorbidity between AD and other diseases, e.g cancers
#     * construction:
#         * overlapping disease modules in the human interactome (PPI network)
#         * analogous overlap in the human metabolom
#         * analogous overlap in the human microRNA network

# %%
from IPython import display

# %% [markdown]
# ## AD candidate gene prioritization
#
# See [Tranchevent et al 2016 Nucleic Acids Research](https://academic.oup.com/nar/article/44/W1/W117/2499350)

# %%
display.Image("/home/attila/figures/from-others/endeavour-2016-Fig1.jpg")

# %% [markdown]
# ## Disease network
#
# See [Goh et al 2007 PNAS](https://www.pnas.org/content/104/21/8685)

# %%
display.Image("/home/attila/figures/from-others/goh-2007-disease-network.png")
